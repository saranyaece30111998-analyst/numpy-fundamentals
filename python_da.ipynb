# %% [markdown]
# <a href="https://colab.research.google.com/github/saranyaece30111998-analyst/numpy-fundamentals/blob/main/python_da.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install NumPy

# %%
import numpy as np

# %%
# 1d array
arr=np.array([1,2,3,4,5,6])
print(arr)
print(type(arr))
# Out:
# [1 2 3 4 5 6]
# <class 'numpy.ndarray'>

# %%
#2d array
arr=np.array([[1,2,3], [4,5,6]])
print(arr)
print(type(arr))
# Out:
# [[1 2 3]
#  [4 5 6]]
# <class 'numpy.ndarray'>

# %%
arr.shape
# Out:
# (2, 3)

# %%
arr.size
# Out:
# 6

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.ndim
# Out:
# 2
